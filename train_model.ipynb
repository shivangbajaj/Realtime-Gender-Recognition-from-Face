# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import img_to_array
from tensorflow.keras.utils import to_categorical, plot_model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import BatchNormalization, Conv2D, MaxPooling2D, Activation, Flatten, Dropout, Dense
from tensorflow.keras import backend as K
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import numpy as np
import random
import cv2
import os
import glob

# initial parameters
epochs = 100
lr = 1e-3
batch_size = 64
img_dims = (96,96,3)

data = []
labels = []

# load image files from the dataset
image_files = [f for f in glob.glob(r'PATH_to_image_data' + "/**/*", recursive=True) if not os.path.isdir(f)]
random.shuffle(image_files)

# converting images to arrays and labelling the categories
for img in image_files:

    image = cv2.imread(img)
    
    image = cv2.resize(image, (img_dims[0],img_dims[1]))
    image = img_to_array(image)
    data.append(image)

    label = img.split(os.path.sep)[-2] # C:\Files\gender_dataset_face\woman\face_1162.jpg
    if label == "woman":
        label = 1
    else:
        label = 0
        
    labels.append([label]) # [[1], [0], [0], ...]

# pre-processing
data = np.array(data, dtype="float") / 255.0
labels = np.array(labels)

# split dataset for training and validation
(trainX, testX, trainY, testY) = train_test_split(data, labels, test_size=0.2,
                                                  random_state=42)

trainY = to_categorical(trainY, num_classes=2) # [[1, 0], [0, 1], [0, 1], ...]
testY = to_categorical(testY, num_classes=2)

# augmenting datset 
aug = ImageDataGenerator(rotation_range=25, width_shift_range=0.1,
                         height_shift_range=0.1, shear_range=0.2, zoom_range=0.2,
                         horizontal_flip=True, fill_mode="nearest")

# define model
def build(width, height, depth, classes):
    model = Sequential()
    inputShape = (height, width, depth)
    chanDim = -1

    if K.image_data_format() == "channels_first": #Returns a string, either 'channels_first' or 'channels_last'
        inputShape = (depth, height, width)
        chanDim = 1
    
    # The axis that should be normalized, after a Conv2D layer with data_format="channels_first", 
    # set axis=1 in BatchNormalization.

    model.add(Conv2D(32, (3,3), padding="same", input_shape=inputShape))
    model.add(Activation("relu"))
    model.add(BatchNormalization(axis=chanDim))
    model.add(MaxPooling2D(pool_size=(3,3)))
    model.add(Dropout(0.25))

    model.add(Conv2D(64, (2,2), padding="same"))
    model.add(Activation("relu"))
    model.add(BatchNormalization(axis=chanDim))

    model.add(Conv2D(64, (2,2), padding="same"))
    model.add(Activation("relu"))
    model.add(BatchNormalization(axis=chanDim))
    model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Dropout(0.25))

    model.add(Conv2D(128, (2,2), padding="same"))
    model.add(Activation("relu"))
    model.add(BatchNormalization(axis=chanDim))

    model.add(Conv2D(128, (2,2), padding="same"))
    model.add(Activation("relu"))
    model.add(BatchNormalization(axis=chanDim))
    model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Dropout(0.25))

    model.add(Flatten())
    model.add(Dense(1024))
    model.add(Activation("relu"))
    model.add(BatchNormalization())
    model.add(Dropout(0.5))

    model.add(Dense(classes))
    model.add(Activation("sigmoid"))

    return model

# build model
model = build(width=img_dims[0], height=img_dims[1], depth=img_dims[2],
                            classes=2)

# compile the model
opt = Adam(lr=lr, decay=lr/epochs)
model.compile(loss="binary_crossentropy", optimizer=opt, metrics=["accuracy"])

# train the model
H = model.fit_generator(aug.flow(trainX, trainY, batch_size=batch_size),
                        validation_data=(testX,testY),
                        steps_per_epoch=len(trainX) // batch_size,
                        epochs=epochs, verbose=1)
# Out:
# WARNING:tensorflow:From <ipython-input-42-c594da6aa825>:121: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# Epoch 1/100
# 28/28 [==============================] - 62s 2s/step - loss: 0.7769 - accuracy: 0.7271 - val_loss: 0.7551 - val_accuracy: 0.4978
# Epoch 2/100
# 28/28 [==============================] - 62s 2s/step - loss: 0.4632 - accuracy: 0.8175 - val_loss: 0.6621 - val_accuracy: 0.6688
# Epoch 3/100
# 28/28 [==============================] - 60s 2s/step - loss: 0.4164 - accuracy: 0.8366 - val_loss: 0.8830 - val_accuracy: 0.5022
# Epoch 4/100
# 28/28 [==============================] - 66s 2s/step - loss: 0.3336 - accuracy: 0.8776 - val_loss: 0.6399 - val_accuracy: 0.6797
# Epoch 5/100
# 28/28 [==============================] - 69s 2s/step - loss: 0.3076 - accuracy: 0.8905 - val_loss: 0.7075 - val_accuracy: 0.5043
# Epoch 6/100
# 28/28 [==============================] - 70s 2s/step - loss: 0.2765 - accuracy: 0.8984 - val_loss: 0.8473 - val_accuracy: 0.5108
# Epoch 7/100
# 28/28 [==============================] - 65s 2s/step - loss: 0.3015 - accuracy: 0.8827 - val_loss: 0.7622 - val_accuracy: 0.5281
# Epoch 8/100
# 28/28 [==============================] - 63s 2s/step - loss: 0.2611 - accuracy: 0.8989 - val_loss: 0.5041 - val_accuracy: 0.8398
# Epoch 9/100
# 28/28 [==============================] - 67s 2s/step - loss: 0.2255 - accuracy: 0.9118 - val_loss: 2.3198 - val_accuracy: 0.5022
# Epoch 10/100
# 28/28 [==============================] - 63s 2s/step - loss: 0.2326 - accuracy: 0.9152 - val_loss: 0.7585 - val_accuracy: 0.5909
# Epoch 11/100
# 28/28 [==============================] - 67s 2s/step - loss: 0.2064 - accuracy: 0.9220 - val_loss: 2.4014 - val_accuracy: 0.5022
# Epoch 12/100
# 28/28 [==============================] - 65s 2s/step - loss: 0.1933 - accuracy: 0.9304 - val_loss: 0.5404 - val_accuracy: 0.7814
# Epoch 13/100
# 28/28 [==============================] - 62s 2s/step - loss: 0.2024 - accuracy: 0.9287 - val_loss: 0.8687 - val_accuracy: 0.6277
# Epoch 14/100
# 28/28 [==============================] - 62s 2s/step - loss: 0.1835 - accuracy: 0.9248 - val_loss: 0.9152 - val_accuracy: 0.6710
# Epoch 15/100
# 28/28 [==============================] - 62s 2s/step - loss: 0.1584 - accuracy: 0.9394 - val_loss: 0.3055 - val_accuracy: 0.8701
# Epoch 16/100
# 28/28 [==============================] - 64s 2s/step - loss: 0.1460 - accuracy: 0.9394 - val_loss: 0.3580 - val_accuracy: 0.8485
# Epoch 17/100
# 28/28 [==============================] - 88s 3s/step - loss: 0.1535 - accuracy: 0.9416 - val_loss: 0.5151 - val_accuracy: 0.8139
# Epoch 18/100
# 28/28 [==============================] - 82s 3s/step - loss: 0.1536 - accuracy: 0.9439 - val_loss: 0.1235 - val_accuracy: 0.9459
# Epoch 19/100
# 28/28 [==============================] - 88s 3s/step - loss: 0.1279 - accuracy: 0.9433 - val_loss: 0.4818 - val_accuracy: 0.8247
# Epoch 20/100
# 28/28 [==============================] - 77s 3s/step - loss: 0.1196 - accuracy: 0.9528 - val_loss: 0.2126 - val_accuracy: 0.9199
# Epoch 21/100
# 28/28 [==============================] - 71s 3s/step - loss: 0.1207 - accuracy: 0.9545 - val_loss: 0.8774 - val_accuracy: 0.7424
# Epoch 22/100
# 28/28 [==============================] - 60s 2s/step - loss: 0.1230 - accuracy: 0.9534 - val_loss: 0.2465 - val_accuracy: 0.9329
# Epoch 23/100
# 28/28 [==============================] - 59s 2s/step - loss: 0.1362 - accuracy: 0.9483 - val_loss: 0.1451 - val_accuracy: 0.9567
# Epoch 24/100
# 28/28 [==============================] - 60s 2s/step - loss: 0.0918 - accuracy: 0.9652 - val_loss: 0.2613 - val_accuracy: 0.9242
# Epoch 25/100
# 28/28 [==============================] - 61s 2s/step - loss: 0.0879 - accuracy: 0.9635 - val_loss: 0.9540 - val_accuracy: 0.7489
# Epoch 26/100
# 28/28 [==============================] - 73s 3s/step - loss: 0.1007 - accuracy: 0.9629 - val_loss: 0.1386 - val_accuracy: 0.9610
# Epoch 27/100
# 28/28 [==============================] - 67s 2s/step - loss: 0.1030 - accuracy: 0.9607 - val_loss: 0.8150 - val_accuracy: 0.7879
# Epoch 28/100
# 28/28 [==============================] - 59s 2s/step - loss: 0.0770 - accuracy: 0.9708 - val_loss: 0.1292 - val_accuracy: 0.9502
# Epoch 29/100
# 28/28 [==============================] - 62s 2s/step - loss: 0.0968 - accuracy: 0.9691 - val_loss: 0.1072 - val_accuracy: 0.9545
# Epoch 30/100
# 28/28 [==============================] - 62s 2s/step - loss: 0.1225 - accuracy: 0.9579 - val_loss: 0.1455 - val_accuracy: 0.9394
# Epoch 31/100
# 28/28 [==============================] - 61s 2s/step - loss: 0.0848 - accuracy: 0.9663 - val_loss: 0.4566 - val_accuracy: 0.8680
# Epoch 32/100
# 28/28 [==============================] - 60s 2s/step - loss: 0.0980 - accuracy: 0.9579 - val_loss: 0.1134 - val_accuracy: 0.9632
# Epoch 33/100
# 28/28 [==============================] - 62s 2s/step - loss: 0.0864 - accuracy: 0.9719 - val_loss: 0.1085 - val_accuracy: 0.9610
# Epoch 34/100
# 28/28 [==============================] - 61s 2s/step - loss: 0.0856 - accuracy: 0.9669 - val_loss: 0.1763 - val_accuracy: 0.9459
# Epoch 35/100
# 28/28 [==============================] - 67s 2s/step - loss: 0.0791 - accuracy: 0.9663 - val_loss: 0.1802 - val_accuracy: 0.9394
# Epoch 36/100
# 28/28 [==============================] - 60s 2s/step - loss: 0.0863 - accuracy: 0.9674 - val_loss: 0.3028 - val_accuracy: 0.9026
# Epoch 37/100
# 28/28 [==============================] - 60s 2s/step - loss: 0.0679 - accuracy: 0.9714 - val_loss: 0.2171 - val_accuracy: 0.9329
# Epoch 38/100
# 28/28 [==============================] - 75s 3s/step - loss: 0.0766 - accuracy: 0.9691 - val_loss: 0.1142 - val_accuracy: 0.9632
# Epoch 39/100
# 28/28 [==============================] - 68s 2s/step - loss: 0.0746 - accuracy: 0.9747 - val_loss: 0.2203 - val_accuracy: 0.9351
# Epoch 40/100
# 28/28 [==============================] - 64s 2s/step - loss: 0.0582 - accuracy: 0.9764 - val_loss: 0.5004 - val_accuracy: 0.8745
# Epoch 41/100
# 28/28 [==============================] - 63s 2s/step - loss: 0.0708 - accuracy: 0.9753 - val_loss: 0.1768 - val_accuracy: 0.9481
# Epoch 42/100
# 28/28 [==============================] - 65s 2s/step - loss: 0.0639 - accuracy: 0.9736 - val_loss: 0.1635 - val_accuracy: 0.9481
# Epoch 43/100
# 28/28 [==============================] - 60s 2s/step - loss: 0.0660 - accuracy: 0.9753 - val_loss: 1.6409 - val_accuracy: 0.7035
# Epoch 44/100
# 28/28 [==============================] - 60s 2s/step - loss: 0.0996 - accuracy: 0.9618 - val_loss: 0.3158 - val_accuracy: 0.8831
# Epoch 45/100
# 28/28 [==============================] - 60s 2s/step - loss: 0.0991 - accuracy: 0.9590 - val_loss: 0.5036 - val_accuracy: 0.8506
# Epoch 46/100
# 28/28 [==============================] - 62s 2s/step - loss: 0.0758 - accuracy: 0.9736 - val_loss: 1.2065 - val_accuracy: 0.7121
# Epoch 47/100
# 28/28 [==============================] - 61s 2s/step - loss: 0.1061 - accuracy: 0.9596 - val_loss: 0.3318 - val_accuracy: 0.8680
# Epoch 48/100
# 28/28 [==============================] - 60s 2s/step - loss: 0.0725 - accuracy: 0.9725 - val_loss: 0.1839 - val_accuracy: 0.9286
# Epoch 49/100
# 28/28 [==============================] - 60s 2s/step - loss: 0.0677 - accuracy: 0.9747 - val_loss: 0.0719 - val_accuracy: 0.9632
# Epoch 50/100
# 28/28 [==============================] - 61s 2s/step - loss: 0.0617 - accuracy: 0.9730 - val_loss: 0.1926 - val_accuracy: 0.9264
# Epoch 51/100
# 28/28 [==============================] - 60s 2s/step - loss: 0.0639 - accuracy: 0.9742 - val_loss: 0.0594 - val_accuracy: 0.9848
# Epoch 52/100
# 28/28 [==============================] - 61s 2s/step - loss: 0.0525 - accuracy: 0.9820 - val_loss: 0.1964 - val_accuracy: 0.9394
# Epoch 53/100
# 28/28 [==============================] - 61s 2s/step - loss: 0.0561 - accuracy: 0.9837 - val_loss: 0.0850 - val_accuracy: 0.9697
# Epoch 54/100
# 28/28 [==============================] - 67s 2s/step - loss: 0.0503 - accuracy: 0.9799 - val_loss: 0.0915 - val_accuracy: 0.9697
# Epoch 55/100
# 28/28 [==============================] - 60s 2s/step - loss: 0.0559 - accuracy: 0.9775 - val_loss: 0.1223 - val_accuracy: 0.9610
# Epoch 56/100
# 28/28 [==============================] - 67s 2s/step - loss: 0.0614 - accuracy: 0.9764 - val_loss: 0.4499 - val_accuracy: 0.8810
# Epoch 57/100
# 28/28 [==============================] - 86s 3s/step - loss: 0.0583 - accuracy: 0.9816 - val_loss: 0.0937 - val_accuracy: 0.9697
# Epoch 58/100
# 28/28 [==============================] - 69s 2s/step - loss: 0.0686 - accuracy: 0.9753 - val_loss: 0.0672 - val_accuracy: 0.9762
# Epoch 59/100
# 28/28 [==============================] - 84s 3s/step - loss: 0.0574 - accuracy: 0.9792 - val_loss: 0.0739 - val_accuracy: 0.9784
# Epoch 60/100
# 28/28 [==============================] - 83s 3s/step - loss: 0.0701 - accuracy: 0.9708 - val_loss: 0.1155 - val_accuracy: 0.9589
# Epoch 61/100
# 28/28 [==============================] - 81s 3s/step - loss: 0.0719 - accuracy: 0.9719 - val_loss: 0.1379 - val_accuracy: 0.9545
# Epoch 62/100
# 28/28 [==============================] - 83s 3s/step - loss: 0.0508 - accuracy: 0.9820 - val_loss: 0.4099 - val_accuracy: 0.8831
# Epoch 63/100
# 28/28 [==============================] - 67s 2s/step - loss: 0.0520 - accuracy: 0.9798 - val_loss: 0.1696 - val_accuracy: 0.9481
# Epoch 64/100
# 28/28 [==============================] - 63s 2s/step - loss: 0.0592 - accuracy: 0.9775 - val_loss: 0.1344 - val_accuracy: 0.9632
# Epoch 65/100
# 28/28 [==============================] - 63s 2s/step - loss: 0.0488 - accuracy: 0.9815 - val_loss: 0.1216 - val_accuracy: 0.9675
# Epoch 66/100
# 28/28 [==============================] - 63s 2s/step - loss: 0.0405 - accuracy: 0.9855 - val_loss: 0.1439 - val_accuracy: 0.9524
# Epoch 67/100
# 28/28 [==============================] - 67s 2s/step - loss: 0.0488 - accuracy: 0.9826 - val_loss: 1.4368 - val_accuracy: 0.7251
# Epoch 68/100
# 28/28 [==============================] - 70s 3s/step - loss: 0.0735 - accuracy: 0.9742 - val_loss: 1.1942 - val_accuracy: 0.7532
# Epoch 69/100
# 28/28 [==============================] - 63s 2s/step - loss: 0.0660 - accuracy: 0.9764 - val_loss: 0.4398 - val_accuracy: 0.8745
# Epoch 70/100
# 28/28 [==============================] - 70s 3s/step - loss: 0.0487 - accuracy: 0.9815 - val_loss: 0.2187 - val_accuracy: 0.9351
# Epoch 71/100
# 28/28 [==============================] - 71s 3s/step - loss: 0.0566 - accuracy: 0.9764 - val_loss: 0.0918 - val_accuracy: 0.9632
# Epoch 72/100
# 28/28 [==============================] - 74s 3s/step - loss: 0.0595 - accuracy: 0.9787 - val_loss: 0.0709 - val_accuracy: 0.9784
# Epoch 73/100
# 28/28 [==============================] - 62s 2s/step - loss: 0.0492 - accuracy: 0.9798 - val_loss: 0.1018 - val_accuracy: 0.9632
# Epoch 74/100
# 28/28 [==============================] - 61s 2s/step - loss: 0.0382 - accuracy: 0.9893 - val_loss: 0.4619 - val_accuracy: 0.8723
# Epoch 75/100
# 28/28 [==============================] - 61s 2s/step - loss: 0.0638 - accuracy: 0.9798 - val_loss: 0.0845 - val_accuracy: 0.9719
# Epoch 76/100
# 28/28 [==============================] - 61s 2s/step - loss: 0.0408 - accuracy: 0.9854 - val_loss: 0.2297 - val_accuracy: 0.9697
# Epoch 77/100
# 28/28 [==============================] - 61s 2s/step - loss: 0.0490 - accuracy: 0.9821 - val_loss: 0.1039 - val_accuracy: 0.9719
# Epoch 78/100
# 28/28 [==============================] - 60s 2s/step - loss: 0.0521 - accuracy: 0.9815 - val_loss: 0.0890 - val_accuracy: 0.9740
# Epoch 79/100
# 28/28 [==============================] - 60s 2s/step - loss: 0.0522 - accuracy: 0.9798 - val_loss: 0.0560 - val_accuracy: 0.9784
# Epoch 80/100
# 28/28 [==============================] - 60s 2s/step - loss: 0.0451 - accuracy: 0.9848 - val_loss: 0.1988 - val_accuracy: 0.9437
# Epoch 81/100
# 28/28 [==============================] - 60s 2s/step - loss: 0.0329 - accuracy: 0.9865 - val_loss: 0.3713 - val_accuracy: 0.9113
# Epoch 82/100
# 28/28 [==============================] - 61s 2s/step - loss: 0.0375 - accuracy: 0.9860 - val_loss: 0.0844 - val_accuracy: 0.9740
# Epoch 83/100
# 28/28 [==============================] - 60s 2s/step - loss: 0.0487 - accuracy: 0.9809 - val_loss: 0.0653 - val_accuracy: 0.9762
# Epoch 84/100
# 28/28 [==============================] - 60s 2s/step - loss: 0.0504 - accuracy: 0.9815 - val_loss: 0.2088 - val_accuracy: 0.9437
# Epoch 85/100
# 28/28 [==============================] - 61s 2s/step - loss: 0.0446 - accuracy: 0.9848 - val_loss: 0.1146 - val_accuracy: 0.9610
# Epoch 86/100
# 28/28 [==============================] - 61s 2s/step - loss: 0.0477 - accuracy: 0.9865 - val_loss: 0.5406 - val_accuracy: 0.8896
# Epoch 87/100
# 28/28 [==============================] - 60s 2s/step - loss: 0.0635 - accuracy: 0.9764 - val_loss: 0.1960 - val_accuracy: 0.9545
# Epoch 88/100
# 28/28 [==============================] - 60s 2s/step - loss: 0.0545 - accuracy: 0.9803 - val_loss: 0.4570 - val_accuracy: 0.8788
# Epoch 89/100
# 28/28 [==============================] - 60s 2s/step - loss: 0.0339 - accuracy: 0.9860 - val_loss: 0.3403 - val_accuracy: 0.9221
# Epoch 90/100
# 28/28 [==============================] - 60s 2s/step - loss: 0.0439 - accuracy: 0.9860 - val_loss: 0.0781 - val_accuracy: 0.9784
# Epoch 91/100
# 28/28 [==============================] - 60s 2s/step - loss: 0.0493 - accuracy: 0.9848 - val_loss: 0.5429 - val_accuracy: 0.8506
# Epoch 92/100
# 28/28 [==============================] - 61s 2s/step - loss: 0.0388 - accuracy: 0.9876 - val_loss: 0.2633 - val_accuracy: 0.9437
# Epoch 93/100
# 28/28 [==============================] - 60s 2s/step - loss: 0.0468 - accuracy: 0.9826 - val_loss: 0.1025 - val_accuracy: 0.9632
# Epoch 94/100
# 28/28 [==============================] - 60s 2s/step - loss: 0.0632 - accuracy: 0.9730 - val_loss: 0.0920 - val_accuracy: 0.9654
# Epoch 95/100
# 28/28 [==============================] - 60s 2s/step - loss: 0.0413 - accuracy: 0.9854 - val_loss: 0.4757 - val_accuracy: 0.8745
# Epoch 96/100
# 28/28 [==============================] - 60s 2s/step - loss: 0.0445 - accuracy: 0.9815 - val_loss: 0.1259 - val_accuracy: 0.9545
# Epoch 97/100
# 28/28 [==============================] - 60s 2s/step - loss: 0.0409 - accuracy: 0.9848 - val_loss: 0.1655 - val_accuracy: 0.9545
# Epoch 98/100
# 28/28 [==============================] - 61s 2s/step - loss: 0.0317 - accuracy: 0.9860 - val_loss: 0.0806 - val_accuracy: 0.9654
# Epoch 99/100
# 28/28 [==============================] - 60s 2s/step - loss: 0.0461 - accuracy: 0.9826 - val_loss: 0.0965 - val_accuracy: 0.9654
# Epoch 100/100
# 28/28 [==============================] - 60s 2s/step - loss: 0.0432 - accuracy: 0.9843 - val_loss: 0.0890 - val_accuracy: 0.9697

# %%
model.save('gender_detection.model')
# Out:
# WARNING:tensorflow:From c:\users\91982\appdata\local\programs\python\python38\lib\site-packages\tensorflow\python\training\tracking\tracking.py:111: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# WARNING:tensorflow:From c:\users\91982\appdata\local\programs\python\python38\lib\site-packages\tensorflow\python\training\tracking\tracking.py:111: Layer.updates (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# INFO:tensorflow:Assets written to: gender_detection.model\assets

# %%
plt.style.use("ggplot")
plt.figure()
N = epochs
plt.plot(np.arange(0,N), H.history["loss"], label="train_loss")
plt.plot(np.arange(0,N), H.history["val_loss"], label="val_loss")
plt.plot(np.arange(0,N), H.history["accuracy"], label="train_accuracy")
plt.plot(np.arange(0,N), H.history["val_accuracy"], label="val_accuracy")

plt.title("Training Loss and Accuracy")
plt.xlabel("Epoch #")
plt.ylabel("Loss/Accuracy")
plt.legend(loc="upper right")

# %%
plt.savefig('plot.png')
